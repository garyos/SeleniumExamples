# %% [markdown]
# <a href="https://colab.research.google.com/github/garyos/SeleniumExamples/blob/master/Selenium.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Selenium Testing

# %% [markdown]
# ## Running a google search through chrome

# %%
# -*- coding: utf-8 -*-
"""
Created on Sat Jul 27 11:05:37 2019

@author: g_osm
"""

from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# create a new chrome session (path added manually to save restart)
driver = webdriver.Chrome(r'C:\Users\g_osm\chromedriver_win32/chromedriver')


#geckodriver needed to be added to path in order for this to work
#driver = webdriver.Firefox()
driver.implicitly_wait(30)
driver.maximize_window()

# Navigate to the application home page
driver.get("http://www.google.com")

# get the search textbox
search_field = driver.find_element_by_name('q')

search_field.clear()

# enter search keyword and submit
search_field.send_keys("Selenium WebDriver Interview questions")
search_field.submit()

# get the list of elements which are displayed after the search
# currently on result page using find_elements_by_class_name method
lists= driver.find_elements_by_class_name("LC20lb")

# get the number of elements found
print ("Found " + str(len(lists)) + " searches:")

# iterate through each element and print the text that is
# name of the search

i=0
for listitem in lists:
   print (listitem.get_attribute("innerHTML"))
   i=i+1
   if(i>10):
      break

# close the browser window
driver.quit()
# Out:
# Found 15 searches:
# 100+ Advanced Selenium Interview Questions (Updated 2019)
# 50 Most Popularly Asked Selenium Interview Questions and Answers
# Top 100 Selenium Interview Questions &amp; Answers - Guru99
# Top Selenium Interview Questions And Answers For 2019 | Edureka
# 100+ Advanced Selenium Interview Questions (Updated 2019)
# 20 Frequently Asked Selenium Interview Questions and Answers
# 20 Most Important Selenium Interview Questions (Frequently Asked)
# Selenium Interview Questions And Answers [Updated for 2019]
# 35 Selenium Webdriver Questions to Succeed in Interviews
# Top 100 Selenium Interview Questions with Answers - ArtOfTesting
# 50 Most Popularly Asked Selenium Interview Questions and Answers

# %% [markdown]
# ## Running a search through firefox (hint just change the web driver)

# %%
#geckodriver needed to be added to path in order for this to work
driver = webdriver.Firefox()
driver.implicitly_wait(30)
driver.maximize_window()

# Navigate to the application home page
driver.get("http://www.google.com")

# get the search textbox
search_field = driver.find_element_by_name('q')

search_field.clear()

# enter search keyword and submit
search_field.send_keys("Selenium WebDriver")
search_field.submit()

# get the list of elements which are displayed after the search
# currently on result page using find_elements_by_class_name method
lists= driver.find_elements_by_class_name("LC20lb")

# get the number of elements found
print ("Found " + str(len(lists)) + " searches:")

# iterate through each element and print the text that is
# name of the search

i=0
for listitem in lists:
   print (listitem.get_attribute("innerHTML"))
   i=i+1
   if(i>10):
      break

# close the browser window
driver.quit()
# Out:
# Found 5 searches:
# Selenium WebDriver
# Selenium WebDriver — Selenium Documentation
# Selenium - Web Browser Automation
# Downloads - Selenium
# What is Selenium WebDriver? Difference with RC - Guru99

# %% [markdown]
# ## With Pagination and Browser Navigation

# %%
#geckodriver needed to be added to path in order for this to work
driver = webdriver.Firefox()
driver.implicitly_wait(30)
driver.maximize_window()

# Navigate to the application home page
driver.get("http://www.google.com")

# get the search textbox
search_field = driver.find_element_by_name('q')

search_field.clear()

# enter search keyword and submit
search_field.send_keys("Selenium WebDriver")
search_field.submit()


#-----------------------------------Pagination--------------------------------------

# Pagination
button = driver.find_element_by_xpath("//span[text()='Next']")
button.click() # page 1

button = driver.find_element_by_xpath("//span[text()='Next']")
button.click() # page 2

#-----------------------------------Browser level navigation-------------------------
driver.back()
driver.forward()
driver.refresh()
#-----------------------------------------------------------------------------------


# iterate through each element and print the text that is
# name of the search


# get the list of elements which are displayed after the search
# currently on result page using find_elements_by_class_name method
lists= driver.find_elements_by_class_name("LC20lb")

# get the number of elements found
print ("Found " + str(len(lists)) + " searches:")

i=0
for listitem in lists:
   print (listitem.get_attribute("innerHTML"))
   i=i+1
   if(i>10):
      break

# close the browser window
driver.quit()
# Out:
# Found 10 searches:
# 7. WebDriver API — Selenium Python Bindings 2 documentation
# All versions of selenium-webdriver | RubyGems.org | your community ...
# webdriver: a Haskell client for the Selenium WebDriver protocol
# Newest 'selenium-webdriver' Questions - Stack Overflow
# Selenium testing with Ruby | BrowserStack
# Mastering Selenium WebDriver: Amazon.co.uk: Mark Collin ...
# Selenium WebDriver integration | Ranorex Studio User Guide
# Selenium WebDriver with Ruby - Test Automation University - Applitools
# How to use Selenium WebDriver in Katalon Studio | Katalon Docs
# Selenium WebDriver Testing - TestPlant eggPlant

# %% [markdown]
# ## Take screenshots while scrolling and test headless (run selenium without showing the window)

# %%
#------------------------Set-headless-------------------------------
from selenium.webdriver.firefox.options import Options


options = Options()
options.headless = True

driver = webdriver.Firefox(options=options)
#driver = webdriver.Firefox()
#--------------------------------------------------------------------


#geckodriver needed to be added to path in order for this to work
#driver = webdriver.Firefox()
driver.implicitly_wait(30)
driver.maximize_window()

# Navigate to the application home page
driver.get("http://www.google.com")

# get the search textbox
search_field = driver.find_element_by_name('q')

search_field.clear()

# enter search keyword and submit
search_field.send_keys("Selenium WebDriver")
search_field.submit()


#-----------------------------------Pagination--------------------------------------

# Pagination
button = driver.find_element_by_xpath("//span[text()='Next']")
button.click() # page 1

button = driver.find_element_by_xpath("//span[text()='Next']")
button.click() # page 2

#-----------------------------------Browser level navigation-------------------------
driver.back()
driver.forward()
driver.refresh()
#---------------------------------------Take a screenshot-----------------------------

body = driver.find_element_by_css_selector('body')
body.send_keys(Keys.PAGE_DOWN)
driver.save_screenshot("screenshot1.png")

body.send_keys(Keys.PAGE_DOWN)
driver.save_screenshot("screenshot2.png")

body.send_keys(Keys.PAGE_DOWN)
driver.save_screenshot("screenshot3.png")
#---------------------------------------------------------------------------------------



# get the list of elements which are displayed after the search
# currently on result page using find_elements_by_class_name method
lists= driver.find_elements_by_class_name("LC20lb")

# get the number of elements found
print ("Found " + str(len(lists)) + " searches:")

i=0
for listitem in lists:
   print (listitem.get_attribute("innerHTML"))
   i=i+1
   if(i>10):
      break

# close the browser window
driver.quit()


from IPython.display import Image

x=Image("./screenshot1.png")

y=Image("./screenshot2.png")

z=Image("./screenshot3.png")

display(x,y,z)
# Out:
# Found 10 searches:
# 7. WebDriver API — Selenium Python Bindings 2 documentation
# All versions of selenium-webdriver | RubyGems.org | your community ...
# webdriver: a Haskell client for the Selenium WebDriver protocol
# Newest 'selenium-webdriver' Questions - Stack Overflow
# Selenium testing with Ruby | BrowserStack
# Mastering Selenium WebDriver: Amazon.co.uk: Mark Collin ...
# Selenium WebDriver integration | Ranorex Studio User Guide
# Selenium WebDriver with Ruby - Test Automation University - Applitools
# How to use Selenium WebDriver in Katalon Studio | Katalon Docs
# Selenium WebDriver Testing - TestPlant eggPlant

# %% [markdown]
# ## BBC politics stories (run headless)

# %%
#------------------------Set-headless-------------------------------
from selenium.webdriver.firefox.options import Options


options = Options()
options.headless = True

driver = webdriver.Firefox(options=options)
#driver = webdriver.Firefox()
#--------------------------------------------------------------------


#geckodriver needed to be added to path in order for this to work
driver.implicitly_wait(30)
driver.maximize_window()



# Navigate to the application home page
driver.get("https://www.bbc.co.uk/news")

lists = driver.find_elements_by_tag_name("h3")

# get the number of elements found
print ("Found " + str(len(lists)) + " searches:")

print(lists[0])

s = set(lists)

i=0
for listitem in s:
   print (listitem.get_attribute("innerHTML"))
   i=i+1
   if(i>(len(lists)/2)):
      break
         
button = driver.find_element_by_xpath("/html/body/div[7]/header/div[2]/div[1]/div[1]/nav/ul/li[5]/a")      
button.click()          


# close the browser window
driver.quit()
# Out:
# Found 115 searches:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="1ae5ee56-d356-4404-95d2-d90397807da5", element="9f3399dc-4012-4543-a146-2744150b6b11")>
# Is Jacob Rees-Mogg right to ban these words?
# The unstoppable rise of Boris Johnson
# Trump: US and UK working on 'very substantial' deal
# US student 'admits' killing Italian policeman
# Mobile app
# Tour de France on final day in Alps
# Noel Edmonds reaches deal with Lloyds over scam
# 'Mass brawl' on British cruise ship
# HK police fire tear gas at unauthorised protest
# Cartoonist captures key moments in LGBTQ+ history
# Boy survives 50ft fall at national park
# News daily newsletter
# 'Mass brawl' on British cruise ship
# What's it like running a Love Islander's Instagram?
# HK police fire tear gas at unauthorised protest
# Rapper ASAP Rocky charged with assault in Sweden
# No-deal Brexit 'threatens' UK science industry
# HK police fire tear gas at unauthorised protest
# Trump: US and UK working on 'very substantial' deal
# Watch: Hull FC hit back to lead in Challenge Cup semi-final
# Fnatic: 15 years at the top of esports
# Hundreds of passengers rescued from flooded train
# Sex and nudity spice up Jane Austen drama
# The artist taking on the 'Essex Girl' stereotype
# Hundreds of passengers rescued from flooded train
# Tour de France on final day in Alps
# US student 'admits' killing Italian policeman
# An incredible mission to separate conjoined twins
# HK police fire tear gas at unauthorised protest
# Supreme Court allows Trump wall funding
# Noel Edmonds reaches deal with Lloyds over scam
# Supreme Court allows Trump wall funding
# Third day of disruption for St Pancras passengers
# England call up Archer for Ashes opener
# Trump: US and UK working on 'very substantial' deal
# Tour de France on final day in Alps
# Supreme Court allows Trump wall funding
# US student 'admits' killing Italian policeman
# Highlights: Ireland all out for 38 as England avoid upset
# PM pledges new northern high-speed rail route
# 'Pack children's medicines in your hand luggage'
# Edinburgh bus driver strike to go ahead
# Hundreds of passengers rescued from flooded train
# Zimbabwe descends into darkness
# Leeds Rhinos win Women's Challenge Cup
# Tour de France on final day in Alps
# Canadian teenage fugitives may be in disguise
# The children with special needs who stay at home
# 'Pack children's medicines in your hand luggage'
# Supreme Court allows Trump wall funding
# 'Pack children's medicines in your hand luggage'
# Why are young homeless people dying in hostels?
# PM pledges new northern high-speed rail route
# The dam that could kill Myanmar's biggest river
# Supreme Court allows Trump wall funding
# Was Thursday the UK's hottest day on record?
# No-deal Brexit 'threatens' UK science industry
# US student 'admits' killing Italian policeman
